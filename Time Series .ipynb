# %%
import random

# %%
L=[]
for i in range(99):
    if ((i//8)%3==1):
        k=(random.normalvariate(0,1))
    if ((i//8)%3==2):
        k=(random.normalvariate(0,0.5) )  
    if ((i//8)%3==0):
        k=(random.normalvariate(0,0.5) + 10)      
    L.append(( k))

# %%
L
# Out:
# [9.45569765945402,
#  10.865117379714103,
#  10.299062148546096,
#  10.719300402144908,
#  10.405611133223037,
#  10.138011457525492,
#  10.3339612679563,
#  10.200381366511296,
#  0.5114688900385924,
#  -0.13337661147388072,
#  0.8634050694000758,
#  -0.8853221572259699,
#  0.35441509756107586,
#  -0.48281872687345706,
#  -1.5108203640692552,
#  -0.926234142510812,
#  0.15607456834393382,
#  -0.09567504315208689,
#  0.3285895785918073,
#  0.0835557096983742,
#  -0.1850314262088026,
#  0.010784068369683533,
#  -0.03656090901037488,
#  0.6646314067461666,
#  9.882261889091309,
#  10.439119585969552,
#  9.735056977736443,
#  10.476043910381861,
#  10.519624281750955,
#  9.780524600794996,
#  9.03596270080443,
#  10.199944807080897,
#  1.105870451224124,
#  -2.132826324711877,
#  -0.9176920827080798,
#  0.21938526465194227,
#  1.8263542362834606,
#  0.21830266987971605,
#  1.8030468134735254,
#  1.4281967671223128,
#  -0.2560909013839314,
#  1.2609936464899585,
#  1.0260496873683762,
# ...

# %%
import numpy as np

# %%
c=0
K=[c]
for i in range (99):
    c=c+L[i]
    K.append(c)

# %%
import matplotlib

# %%
K
# Out:
# [0,
#  9.45569765945402,
#  20.320815039168124,
#  30.61987718771422,
#  41.339177589859126,
#  51.744788723082166,
#  61.88280018060766,
#  72.21676144856396,
#  82.41714281507525,
#  82.92861170511384,
#  82.79523509363996,
#  83.65864016304003,
#  82.77331800581406,
#  83.12773310337514,
#  82.64491437650167,
#  81.13409401243241,
#  80.2078598699216,
#  80.36393443826555,
#  80.26825939511346,
#  80.59684897370526,
#  80.68040468340364,
#  80.49537325719483,
#  80.50615732556452,
#  80.46959641655414,
#  81.13422782330031,
#  91.01648971239162,
#  101.45560929836117,
#  111.19066627609762,
#  121.66671018647948,
#  132.18633446823043,
#  141.96685906902542,
#  151.00282176982984,
#  161.20276657691073,
#  162.30863702813485,
#  160.17581070342297,
#  159.2581186207149,
#  159.47750388536684,
#  161.3038581216503,
#  161.52216079153,
#  163.32520760500353,
#  164.75340437212583,
#  164.4973134707419,
#  165.75830711723185,
#  166.78435680460024,
#  165.93179300738146,
# ...

# %%
from matplotlib import pyplot as plt

# %%
x=np.arange(100)

# %%
plt.plot(x,K)

# %%
M=[]
for i in range(len(K)-1):
    M.append(K[i+1]-K[i])

# %%
L
# Out:
# [9.45569765945402,
#  10.865117379714103,
#  10.299062148546096,
#  10.719300402144908,
#  10.405611133223037,
#  10.138011457525492,
#  10.3339612679563,
#  10.200381366511296,
#  0.5114688900385924,
#  -0.13337661147388072,
#  0.8634050694000758,
#  -0.8853221572259699,
#  0.35441509756107586,
#  -0.48281872687345706,
#  -1.5108203640692552,
#  -0.926234142510812,
#  0.15607456834393382,
#  -0.09567504315208689,
#  0.3285895785918073,
#  0.0835557096983742,
#  -0.1850314262088026,
#  0.010784068369683533,
#  -0.03656090901037488,
#  0.6646314067461666,
#  9.882261889091309,
#  10.439119585969552,
#  9.735056977736443,
#  10.476043910381861,
#  10.519624281750955,
#  9.780524600794996,
#  9.03596270080443,
#  10.199944807080897,
#  1.105870451224124,
#  -2.132826324711877,
#  -0.9176920827080798,
#  0.21938526465194227,
#  1.8263542362834606,
#  0.21830266987971605,
#  1.8030468134735254,
#  1.4281967671223128,
#  -0.2560909013839314,
#  1.2609936464899585,
#  1.0260496873683762,
# ...

# %%
y=np.arange(len(M))

# %%
plt.plot(y,M)

# %%
t=np.array(L)

# %%
plot_acf(t)

# %%
plot_pacf(t)

# %%
L=[]
for i in range(100):
    L.append(np.sqrt(i))

# %%
plt.plot(x,L)

# %%
s=0
for i in L:
    s+=i
print (s/100)
# Out:
# 6.614629471031477

# %%
from statsmodels.graphics.tsaplots import plot_pacf,acf
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import adfuller as ad
from statsmodels.tsa.ar_model import AutoReg

# %%
t=np.array(L)

# %%
plot_acf(t)

# %%
t=np.array(L)
plot_acf(t)

# %%
t=np.array(L)
plot_pacf(t)

# %%
t=np.array(L)
plot_acf(t)

# %%
V=[]
for i in range (100):
    V.append(10 + np.random.normal(0,0.01))

# %%
t1=np.array(V)

# %%
plt.plot(x,t1)

# %%
x=np.arange(100)
